# %% [markdown]
# # Beeswarm graphic data formatting

# %%
import feather
import pandas as pd

# %% [markdown]
# ## Load data

# %%
df = feather.read_dataframe('data/processed/company-revenues.feather')

print(len(df))

df.head()
# Out:
# 2891
#    Symbol                                             Name  \
# 0  BLDY62                                    Rhipe Limited
# 1  661448                                      Webzen Inc.
# 2  B03MXR             Turkiye Sise ve Cam Fabrikalari A.S.
# 3  BF1GQB  P.C.S. Machine Group Holding Public Company Ltd
# 4    VBIV                               VBI Vaccines, Inc.
#
#                                        Proper Name  china_rev_18  \
# 0                                    Rhipe Limited     15.458523
# 1                                      Webzen Inc.     45.966671
# 2             Turkiye Sise ve Cam Fabrikalari A.S.     90.761591
# 3  P.C.S. Machine Group Holding Public Company Ltd     22.611381
# 4                               VBI Vaccines, Inc.      2.590077
#
#    china_rev_17  china_rev_16  confidence_18  confidence_17     country_hq  \
# 0      0.095392      0.480210       0.992843       0.999522      Australia
# 1      0.328330      0.202569       0.993882       0.999543    South Korea
# 2      0.702733      0.657526       0.996689       0.999964         Turkey
# 3      0.323594      0.091828       0.980272       0.999418       Thailand
# 4      0.043343      0.043849       0.979546       0.994639  United States
#
#                     curated_sector   growth_18  growth_17  faster_18  \
# 0        Heavy industry, machinery  16105.1969   -80.1353       True
# 1           IT, software, internet  13900.1495    62.0827       True
# 2  Light manufacturing, processing  12815.5167     6.8753       True
# 3        Heavy industry, machinery   6887.5744   252.3908       True
# 4   Health services and technology   5875.7547    -1.1541       True
#
#    growth_18_z growth_18_p
# 0    28.634923         100
# 1    24.692860         100
# 2    22.753813         100
# 3    12.156162         100
# 4    10.347287         100

# %%
df.dtypes
# Out:
# Symbol              object
# Name                object
# Proper Name         object
# china_rev_18       float64
# china_rev_17       float64
# china_rev_16       float64
# confidence_18      float64
# confidence_17      float64
# country_hq          object
# curated_sector      object
# growth_18          float64
# growth_17          float64
# faster_18             bool
# growth_18_z        float64
# growth_18_p       category
# dtype: object

# %% [markdown]
# ## Sort sectors by aggregate revenue growth (inclusive of outliers) and format for D3 viz
#
# _Filter out companies with growth > 100 per cent_

# %%
sort_order = df.copy() \
    .groupby('curated_sector', as_index=False)['china_rev_18', 'china_rev_17'].sum() \
    .assign(aggregate_growth_18 = lambda x:
        round((x['china_rev_18'] - x['china_rev_17']) / x['china_rev_17'], 3) * 100
    ) \
    .drop('china_rev_17', axis=1) \
    .sort_values('aggregate_growth_18', ascending=False)['curated_sector'].tolist()

sort_order
# Out:
# ['Energy and mining',
#  'IT, software, internet',
#  'Health services and technology',
#  'Electronic equipment, semiconductors, aerospace, defense',
#  'Heavy industry, machinery',
#  'Light manufacturing, processing',
#  'Others',
#  'Consumer and autos',
#  'Retail, wholesale, logistics, shipping']

# %%
df_beeswarm = df.copy() \
    .query('growth_18 <= 100') \
    .assign(curated_sector = lambda x: pd.Categorical(x['curated_sector'], sort_order)) \
    .assign(colour = 'Positive') \
    .rename({
        'Name': 'name',
        'china_rev_18': 'radius',
        'curated_sector': 'category',
        'confidence_18': 'opacity',
        'growth_18': 'value'
    }, axis=1) \
    .drop('china_rev_17', axis=1) \
    .sort_values(['category', 'value'], ascending=[True, False]) \
    .reset_index(drop=True)

print(len(df_beeswarm))

df_beeswarm.head()
# Out:
# 2454
#    Symbol                                      name  \
# 0  633258                     Fauji Cement Co. Ltd.
# 1  B59FPC                         Novolipetsk Steel
# 2  BWSW5D                              South32 Ltd.
# 3  B03MS9  Eregli Demir ye celik Fabrikalari T.A.S.
# 4    ARCH                     Arch Coal Inc Class A
#
#                                 Proper Name      radius  china_rev_16  \
# 0                     Fauji Cement Co. Ltd.    1.500558      2.414669
# 1                         Novolipetsk Steel  100.719979     61.976106
# 2                              South32 Ltd.  362.241709    242.838379
# 3  Eregli Demir ye celik Fabrikalari T.A.S.  187.716484     75.201763
# 4                     Arch Coal Inc Class A  133.815749     24.286804
#
#     opacity  confidence_17          country_hq           category    value  \
# 0  0.998712       0.999187            Pakistan  Energy and mining  97.9512
# 1  0.998952       0.999154  Russian Federation  Energy and mining  88.0741
# 2  0.998684       0.999062           Australia  Energy and mining  76.5257
# 3  0.994640       0.995609              Turkey  Energy and mining  73.5279
# 4  0.995240       0.996563       United States  Energy and mining  72.9279
#
#    growth_17  faster_18  growth_18_z growth_18_p    colour
# 0   -68.6067       True     0.018046          85  Positive
# 1   -13.5903       True     0.000388          84  Positive
# 2   -15.4968       True    -0.020257          82  Positive
# 3    43.8484       True    -0.025617          82  Positive
# 4   218.6190      False    -0.026689          82  Positive

# %%
df_beeswarm.tail()
# Out:
#       Symbol                                    name  \
# 2449  608498               Salalah Port Services Co.
# 2450    MATX                            Matson, Inc.
# 2451  656175  Thoresen Thai Agencies Public Co. Ltd.
# 2452     GWR         Genesee & Wyoming, Inc. Class A
# 2453  659266                              Sinwa Ltd.
#
#                                  Proper Name      radius  china_rev_16  \
# 2449               Salalah Port Services Co.    0.162115      0.355388
# 2450                            Matson, Inc.  108.015166    707.444987
# 2451  Thoresen Thai Agencies Public Co. Ltd.   19.203519     13.397906
# 2452         Genesee & Wyoming, Inc. Class A    2.614688     13.313657
# 2453                              Sinwa Ltd.    0.000860      0.763432
#
#        opacity  confidence_17     country_hq  \
# 2449  0.999861       0.999521           Oman
# 2450  0.974276       0.979675  United States
# 2451  0.980549       0.975655       Thailand
# 2452  0.999878       0.998995  United States
# 2453  0.997030       0.997030      Singapore
#
#                                     category    value  growth_17  faster_18  \
# 2449  Retail, wholesale, logistics, shipping -75.5932    86.9010      False
# 2450  Retail, wholesale, logistics, shipping -77.1694   -33.1234      False
# 2451  Retail, wholesale, logistics, shipping -78.6565   571.5490      False
# 2452  Retail, wholesale, logistics, shipping -83.4216    18.4619      False
# 2453  Retail, wholesale, logistics, shipping -99.9526   137.5254      False
#
#       growth_18_z growth_18_p    colour
# 2449    -0.292207           3  Positive
# 2450    -0.295025           3  Positive
# 2451    -0.297684           2  Positive
# 2452    -0.306203           2  Positive
# 2453    -0.335756           1  Positive

# %%
df_beeswarm.to_csv('data/processed/beeswarm-companies.csv', index=False)

# %% [markdown]
# ## Aggregate companies with growth > 100 per cent

# %%
df_gt_100 = df.copy() \
    .query('growth_18 > 100') \
    .assign(
        curated_sector = lambda x: pd.Categorical(x['curated_sector'], sort_order)
    ) \
    .groupby('curated_sector', as_index=False)['china_rev_18', 'Name'].agg({
        'china_rev_18': 'sum',
        'Name': 'count'
    }) \
    .rename({
        'china_rev_18': 'radius',
        'Name': 'companies_count'
    }, axis=1)

print(len(df_gt_100))

df_gt_100
# Out:
# 9
#                                       curated_sector        radius  \
# 0                                  Energy and mining  92198.184267
# 1                             IT, software, internet    980.224084
# 2                     Health services and technology  14196.636486
# 3  Electronic equipment, semiconductors, aerospac...   4484.293553
# 4                          Heavy industry, machinery  10178.508213
# 5                    Light manufacturing, processing  11287.499673
# 6                                             Others   6994.207543
# 7                                 Consumer and autos  14948.664646
# 8             Retail, wholesale, logistics, shipping   3961.454867
#
#    companies_count
# 0               29
# 1               43
# 2               39
# 3               48
# 4               69
# 5               47
# 6               64
# 7               71
# 8               27

# %% [markdown]
# ## Format sectoral data for small- and medium-sized graphics

# %%
df_beeswarm_s = feather.read_dataframe('data/processed/sector-revenues.feather') \
    .assign(
        curated_sector = lambda x: pd.Categorical(x['curated_sector'], sort_order)
    ) \
    .rename({
        'curated_sector': 'name',
        'china_rev_18': 'radius_18',
        'china_rev_17': 'radius_17',
        'confidence_18': 'opacity_18',
        'confidence_17': 'opacity_17',
        'sector_growth_18': 'value_18',
        'sector_growth_17': 'value_17'
    }, axis=1) \
    .drop('slower_18', axis=1) \
    .sort_values('name') \
    .reset_index(drop=True)
    

df_beeswarm_s
# Out:
#                                                 name      radius_18  \
# 0                                  Energy and mining  242016.741407
# 1                             IT, software, internet   47642.046425
# 2                     Health services and technology   59225.919681
# 3  Electronic equipment, semiconductors, aerospac...  274578.018589
# 4                          Heavy industry, machinery  123882.054476
# 5                    Light manufacturing, processing  102447.873262
# 6                                             Others   40823.692907
# 7                                 Consumer and autos  170877.860873
# 8             Retail, wholesale, logistics, shipping   69476.606155
#
#        radius_17  opacity_18  opacity_17  value_18  value_17
# 0  163185.375811    0.995139    0.994462   48.3079   31.4231
# 1   37938.649907    0.995452    0.994811   25.5765   15.6723
# 2   48955.624952    0.995464    0.994873   20.9788   11.4335
# 3  233920.840281    0.994018    0.993183   17.3807    8.7726
# 4  106652.015991    0.995311    0.994859   16.1554    9.7131
# 5   88986.807666    0.994462    0.993809   15.1270   13.4077
# 6   37357.881197    0.996099    0.995603    9.2773   31.9221
# 7  157625.254803    0.995335    0.994918    8.4077    9.8821
# 8   69695.619982    0.995452    0.995277   -0.3142    6.1380

# %%
df_beeswarm_s_18 = df_beeswarm_s[['name', 'radius_18', 'opacity_18', 'value_18']].copy() \
    .assign(category = '2018') \
    .rename({
        'radius_18': 'radius',
        'opacity_18': 'opacity',
        'value_18': 'value'
    }, axis=1)

df_beeswarm_s_18
# Out:
#                                                 name         radius   opacity  \
# 0                                  Energy and mining  242016.741407  0.995139
# 1                             IT, software, internet   47642.046425  0.995452
# 2                     Health services and technology   59225.919681  0.995464
# 3  Electronic equipment, semiconductors, aerospac...  274578.018589  0.994018
# 4                          Heavy industry, machinery  123882.054476  0.995311
# 5                    Light manufacturing, processing  102447.873262  0.994462
# 6                                             Others   40823.692907  0.996099
# 7                                 Consumer and autos  170877.860873  0.995335
# 8             Retail, wholesale, logistics, shipping   69476.606155  0.995452
#
#      value category
# 0  48.3079     2018
# 1  25.5765     2018
# 2  20.9788     2018
# 3  17.3807     2018
# 4  16.1554     2018
# 5  15.1270     2018
# 6   9.2773     2018
# 7   8.4077     2018
# 8  -0.3142     2018

# %%
df_beeswarm_s_17 = df_beeswarm_s[['name', 'radius_17', 'opacity_17', 'value_17']].copy() \
    .assign(category = '2017') \
    .rename({
        'radius_17': 'radius',
        'opacity_17': 'opacity',
        'value_17': 'value'
    }, axis=1)

df_beeswarm_s_17
# Out:
#                                                 name         radius   opacity  \
# 0                                  Energy and mining  163185.375811  0.994462
# 1                             IT, software, internet   37938.649907  0.994811
# 2                     Health services and technology   48955.624952  0.994873
# 3  Electronic equipment, semiconductors, aerospac...  233920.840281  0.993183
# 4                          Heavy industry, machinery  106652.015991  0.994859
# 5                    Light manufacturing, processing   88986.807666  0.993809
# 6                                             Others   37357.881197  0.995603
# 7                                 Consumer and autos  157625.254803  0.994918
# 8             Retail, wholesale, logistics, shipping   69695.619982  0.995277
#
#      value category
# 0  31.4231     2017
# 1  15.6723     2017
# 2  11.4335     2017
# 3   8.7726     2017
# 4   9.7131     2017
# 5  13.4077     2017
# 6  31.9221     2017
# 7   9.8821     2017
# 8   6.1380     2017

# %%
df_beeswarm_s_joined = pd.concat([df_beeswarm_s_17, df_beeswarm_s_18], sort=False) \
    .assign(colour = 'Positive')

df_beeswarm_s_joined
# Out:
#                                                 name         radius   opacity  \
# 0                                  Energy and mining  163185.375811  0.994462
# 1                             IT, software, internet   37938.649907  0.994811
# 2                     Health services and technology   48955.624952  0.994873
# 3  Electronic equipment, semiconductors, aerospac...  233920.840281  0.993183
# 4                          Heavy industry, machinery  106652.015991  0.994859
# 5                    Light manufacturing, processing   88986.807666  0.993809
# 6                                             Others   37357.881197  0.995603
# 7                                 Consumer and autos  157625.254803  0.994918
# 8             Retail, wholesale, logistics, shipping   69695.619982  0.995277
# 0                                  Energy and mining  242016.741407  0.995139
# 1                             IT, software, internet   47642.046425  0.995452
# 2                     Health services and technology   59225.919681  0.995464
# 3  Electronic equipment, semiconductors, aerospac...  274578.018589  0.994018
# 4                          Heavy industry, machinery  123882.054476  0.995311
# 5                    Light manufacturing, processing  102447.873262  0.994462
# 6                                             Others   40823.692907  0.996099
# 7                                 Consumer and autos  170877.860873  0.995335
# 8             Retail, wholesale, logistics, shipping   69476.606155  0.995452
#
#      value category    colour
# 0  31.4231     2017  Positive
# 1  15.6723     2017  Positive
# 2  11.4335     2017  Positive
# 3   8.7726     2017  Positive
# 4   9.7131     2017  Positive
# 5  13.4077     2017  Positive
# 6  31.9221     2017  Positive
# 7   9.8821     2017  Positive
# 8   6.1380     2017  Positive
# 0  48.3079     2018  Positive
# 1  25.5765     2018  Positive
# 2  20.9788     2018  Positive
# 3  17.3807     2018  Positive
# 4  16.1554     2018  Positive
# 5  15.1270     2018  Positive
# 6   9.2773     2018  Positive
# 7   8.4077     2018  Positive
# 8  -0.3142     2018  Positive

# %%
df_beeswarm_s_joined.to_csv('data/processed/beeswarm-sectors.csv', index=False)
